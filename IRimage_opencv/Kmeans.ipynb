# %% [markdown]
# Reference: https://docs.opencv.org/4.x/d1/d5c/tutorial_py_kmeans_opencv.html

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage import measure, morphology
# %matplotlib inline

# %%
imgc = cv2.imread('/Users/zhangtianjie/Documents/GitHub/IR_image_process/IRimages/matlab_20220523_114719/20220523_114719_IR.jpg')
def imgconvert(img):
    b,g,r=cv2.split(img)
    img=cv2.merge((r,g,b))
    return img
imgc=imgconvert(imgc)
plt.imshow(imgc)
plt.axis('off')
plt.title('RGB image')
# Out:
# Text(0.5, 1.0, 'RGB image')

# %%
# image = cv2.imread('IMG_1127.jpg')
# image.shape


data = imgc.reshape((-1,3))
data = np.float32(data)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
num_clusters = 3
ret,label,center=cv2.kmeans(data, num_clusters, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((imgc.shape))
plt.imshow(res2)
plt.axis('off')
plt.title('Kmeans')
# cv2.imshow('res2',res2)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Text(0.5, 1.0, 'Kmeans')
